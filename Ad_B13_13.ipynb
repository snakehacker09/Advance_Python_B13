# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
creation of a piechart by using a matplotlib:

# %%
#data to plot

# %%
labels = 'python','c++','ruby','java'
sizes = [217,120,215,210]
colors = ['gold','yellowgreen','lightcoral','lightskyblue']
explode = (0.1,0,0,0)

# %%
#plotting the pie chart

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
labels = 'apple','orange','guava','grapes'
sizes = [50,100,80,40]
colors = ['blue','red','pink','yellow']
explode = (0.1,0,0,0)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
labels = 'ayush','priyanka','soniya','akash'
sizes = [99,68,55,80]
colors = ['yellow','pink','red','orange']
explode = (0.2,0,0,0)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True, startangle=140)
plt.axis('equal')
plt.show()
