# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]

# %%
plt.plot(x,y)
plt.show()

# %%
req: create a sales graph, where in yours x axis as sales and y axis as revenue

# %%
plt.xlabel('sales')
plt.ylabel('revenue')
plt.plot(x,y)
plt.show()

# %%
req: give the name to the graph name as 'sales performance'

# %%
plt.title('sales performance')
plt.xlabel('sales')
plt.ylabel('revenue')
plt.plot(x,y)
plt.show()

# %%
z = [10,5,10]
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
labelling method:

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.legend(['this is x and y','this is x and z'])
plt.show()

# %%
complete graph:

# %%
plt.title('sales performance')
plt.xlabel('sales')
plt.ylabel('revenue')
plt.plot(x,y)
plt.plot(x,z)
plt.legend(['this is x and y','this is x and z'])
plt.show()
